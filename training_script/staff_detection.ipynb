# %%
# %cd yolov7
# Out:
# /home/jupyter-caiyee/yolov7
# /opt/tljh/user/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import torch
from utils.general import non_max_suppression
from models.experimental import attempt_load
from utils.datasets import LoadImages
from utils.plots import plot_one_box
from torchvision import models
from torchsummary import summary

# %%
# Load both models
model_person = attempt_load('runs/train/exp5/weights/best.pt', map_location=torch.device('cuda')) 
model_name_tags = attempt_load('runs/train/exp9/weights/best.pt', map_location=torch.device('cuda'))
# Out:
# Fusing layers...
# IDetect.fuse
# Fusing layers...
# IDetect.fuse

# %%
# Test the model to detect person in the sample video
# !python detect.py --weights 'runs/train/exp5/weights/best.pt' --conf 0.25 --img-size 640 --source  '../sample.mp4'
# Out:
# Namespace(weights=['runs/train/exp5/weights/best.pt'], source='../sample.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.2.2 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191.5MB)
#
# Fusing layers...
# IDetect.fuse
# /opt/tljh/user/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 208 layers, 6007596 parameters, 0 gradients, 13.0 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
# Test the model to detect name tag in the sample video
# !python detect.py --weights 'runs/train/exp9/weights/best.pt' --conf 0.25 --img-size 640 --source  '../sample.mp4'
# Out:
# Namespace(weights=['runs/train/exp5/weights/best.pt'], source='../sample.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.2.2 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191.5MB)
#
# Fusing layers...
# IDetect.fuse
# /opt/tljh/user/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 208 layers, 6007596 parameters, 0 gradients, 13.0 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
# Check if the name tag bounding box is contained within the person bounding box
# If yes, thsi is valid
# only displayed the valid staff
# !python detect_test.py --weights1 'runs/train/exp5/weights/best.pt' --weights2 'runs/train/exp9/weights/best.pt' --conf 0.25 --img-size 640 --source '../test.mp4'
# Out:
# Namespace(weights1='runs/train/exp5/weights/best.pt', weights2='runs/train/exp9/weights/best.pt', source='../test.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.2.2 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191.5MB)
#
# Fusing layers...
# IDetect.fuse
# /opt/tljh/user/lib/python3.10/site-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1711403380909/work/aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 208 layers, 6007596 parameters, 0 gradients, 13.0 GFLOPS
# Fusing layers...
# IDetect.fuse
# ...
